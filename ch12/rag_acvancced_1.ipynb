# %%
import os
from dotenv import load_dotenv

load_dotenv()
openai_api_key = os.getenv("OPENAI_API_KEY")

if not openai_api_key:
    raise ValueError("OpenAI API key not found.")

os.environ["OPENAI_API_KEY"] = openai_api_key
# Out:
# USER_AGENT environment variable not set, consider setting it to identify your requests.

# %%
import bs4
from langchain_classic import hub
from langchain_text_splitters import RecursiveCharacterTextSplitter
from langchain_community.document_loaders import WebBaseLoader
from langchain_community.vectorstores import Chroma
from langchain_core.output_parsers import StrOutputParser
from langchain_core.runnables import RunnablePassthrough
from langchain_openai import ChatOpenAI , OpenAIEmbeddings

# Load Documents

loader = WebBaseLoader(
    web_path=("https://news.naver.com/section/101",),
    bs_kwargs=dict(
        parse_only=bs4.SoupStrainer(
            class_=("sa_text", "sa_item_SECTION_HEADLINE")
        )
    ),
)

docs = loader.load()

# %%
docs
# Out:
# [Document(metadata={'source': 'https://news.naver.com/section/101'}, page_content='\n\n주식 뜨자 18년 만에 최대 성장…펀드시장 순자산 1300兆 돌파\n\n지난해부터 이어진 증시 호조로 주식형 펀드에 대한 자금 유입이 급증하면서 국내 펀드 시장 순자산총액이 1376조원을 넘어서며 역대 최고 성장률을 기록했다. 27일 금융투자협회가 공개한 \'2025년 펀드시장 결산\'에\n\n\n매일신문\n\n\n\n\n19\n개의 관련뉴스 더보기\n\n\n\n\n\nLG이노텍 지난해 영업이익 6650억원…전년比 5.8%↓\n\nLG이노텍이 지난해 연결 기준 영업이익(잠정치)이 6650억원으로 전년 대비 5.8% 감소했다고 공시했다. 매출은 21조8966억원으로 같은 기간 3.3% 늘었다. 순이익은 3413억원으로 24% 줄었다. 지난해 4\n\n\n아시아경제\n\n\n\n\n26\n개의 관련뉴스 더보기\n\n\n\n\n\n롯데렌탈·SK렌터카 기업결합 불허…롯데 "공정위 심사결과 존중"\n\n공정거래위원회가 26일 국내 1, 2위 렌터카 업체 SK렌터카와 롯데렌탈의 기업결합을 불허한 것과 관련해 롯데그룹은 "공정위 기업결합 심사 결과의 취지를 존중한다"고 밝혔다. 롯데그룹은 이날 공식 입장문을 통해 "향\n\n\n데일리안\n\n\n\n\n78\n개의 관련뉴스 더보기\n\n\n\n\n\n같은 자영업자인데 "다 베꼈다" 분노…파리바게뜨에 무슨 일이 [이슈+]\n\n\'두바이 쫀득 쿠키\'(두쫀쿠) 열풍이 이어지는 가운데 SPC그룹이 운영하는 베이커리 프랜차이즈 파리바게뜨가 일부 자영업자들로부터 "벼룩의 간을 빼 먹어라"는 비판을 받았다. 두쫀쿠 유사품을 출시한 대기업 파리바게뜨가\n\n\n한국경제\n\n\n\n\n23\n개의 관련뉴스 더보기\n\n\n\n\n\n李정부, 탈원전 유턴…3기 예정대로 짓는다\n\n정부가 신규 원자력발전소 3기 건설을 예정대로 추진하기로 했다. 이재명 대통령이 지난해 9월 취임 100일을 맞아 열린 기자회견에서 “인공지능(AI) 때문에 필요하다는데 신규 원전은 15년이 걸려 현실성이 없다”며\n\n\n서울경제\n\n\n\n\n128\n개의 관련뉴스 더보기\n\n\n\n\n\n국제 금값 사상 첫 5천불 돌파…전문가들 "당분간 우상향세"\n\n트럼프 \'FAFO\'·연준 독립성 약화 등 불확실성에 헤지수요 급증 국제 금 시세가 가파르게 치솟으면서 금 현물 가격이 사상 처음으로 온스당 5천달러를 돌파함에 따라 향후 방향성에 관심이 쏠린다. 26일 금융정보서비스\n\n\n연합뉴스\n\n\n\n\n30\n개의 관련뉴스 더보기\n\n\n\n\n\n삼성바이오에피스 사상최대 실적, 연매출 1조6720억원 … 9% 늘어\n\n삼성바이오에피스가 지난해 연간 매출 1조6720억원, 영업이익 3759억원을 기록하며 연 매출 기준 역대 최대 기록을 썼다. 미국과 유럽 등 글로벌 시장에서 바이오시밀러(바이오의약품 복제약) 판매가 꾸준히 늘어난 결\n\n\n매일경제\n\n\n\n\n23\n개의 관련뉴스 더보기\n\n\n\n\n\n‘천스닥’ 회복에 레버리지 투자 러시… 금투협 교육 사이트 ‘먹통’\n\n코스피 지수가 사상 최초로 5000선을 돌파하고, 코스닥이 4년 만에 ‘천스닥’(코스닥 1000) 회복에 성공하면서 개인 투자자들의 관심이 레버리지 상품으로 집중되고 있다. 이에 따라 관련 상품 거래를 위한 사전 교\n\n\n조선비즈\n\n\n\n\n24\n개의 관련뉴스 더보기\n\n\n\n\n\n경제계 “배임죄, 조건없이 전면 개편해야”\n\n경제 8단체 배임죄 개선 호소문 과도한 경제형벌, 경영·투자 위축 형법·상법·특경법상 손질 요구 “美·英처럼 사기·횡령죄 처벌해야” 경영판단원칙 명문화 리스크 완화 서울 용산구 드래곤시티호텔에서 경제8단체 부회장들이\n\n\n헤럴드경제\n\n\n\n\n34\n개의 관련뉴스 더보기\n\n\n\n\n\n한화證, 우호적 업황에 실적 반전…영업이익 3616%↑\n\n한화투자증권이 지난해 우호적인 업황에 힘입어 직전 연도 대비 3616% 증가한 영업이익을 기록했다. 26일 한화투자증권은 공시를 통해 2025년 연결 기준 영업이익이 1473억 9100만 원으로 집계됐다고 밝혔다.\n\n\n서울경제\n\n\n\n\n11\n개의 관련뉴스 더보기\n\n\n\n\n\n美 강력한 겨울폭풍…정전·항공편취소·천연가스값 폭등\n\n이 기사는 국내 최대 해외 투자정보 플랫폼 한경 글로벌마켓에 게재된 기사입니다. 미국에서 강력한 겨울 폭풍이 전국을 휩쓸면서 미국내 수십만 가구가 정전되고 대규모 항공편 취소가 발생한 가운데 천연가스 가격이 2022\n\n\n한국경제\n\n32분전\n\n\n\n\n\n\n\n\n대통령 ‘중복상장’ 저격에 LS 에식스 철회…대기업 자회사들 눈치게임\n\n에식스솔루션, 예심 전격 철회 2억달러 프리IPO 상환 부담에 홍콩·미국 해외상장 가능성도 HD현대·SK·한화그룹등 촉각 알짜자회사 해외이탈 우려도 LS그룹이 권선 계열사 에식스솔루션즈 기업공개(IPO)를 중단했다.\n\n\n매일경제\n\n43분전\n\n\n\n\n\n\n\n\n국민연금, 국내주식 보유 한도 넘어도 기계적 매도 한시 유예 [시그널]\n\n국민연금이 국내 주식 비중을 재조정한 것은 코스피 5000 시대가 열려도 기계적 매도에 나설 수밖에 없는 상황 때문이다. 국민의 노후 자금을 책임지는 기금으로서 수익률을 극대화해야 하지만 제한된 한도로 인해 시장 수\n\n\n서울경제\n\n1시간전\n\n\n\n\n\n\n\n\n\'삼전·하닉·현차\' 주가 떨어졌는데…개미들 미소짓는 이유 [분석+]\n\n국내 증시 시가총액 1~3위 삼성전자, SK하이닉스, 현대차가 26일 주식시장에서 동반 숨 고르기에 들어갔다. 이들 기업 모두 오는 29일 지난해 4분기 실적 발표가 예정돼 있어 성적표를 확인한 뒤 추가 반등을 노릴\n\n\n한국경제\n\n1시간전\n\n\n\n\n\n\n\n\n코스닥 \'천스닥\' 달성…7%대 급등에 사이드카 발동\n\n코스피가 5,000선을 돌파한 데 이어 코스닥지수가 4년여만에 1,000선을 넘었습니다. 코스닥지수가 7% 넘게 급등해 9개월 만에 매수 사이드카도 발동됐는데요. 종가는 이른바 \'닷컴버블\' 이후 25년여 만에 최고를\n\n\n연합뉴스TV\n\n1시간전\n\n\n\n\n\n\n\n\n케이조선 매각 상황은?…“노동자 참여 보장해야”\n\n[앵커] 매각 절차가 진행 중인 옛 STX 조선, 케이조선이 지난해 영업 이익이 1조 원을 넘길 것으로 전망됩니다. 이에 따라 기업 가치가 적게는 5천 억 원에서 많게는 1조 원까지 거론되고 있는 데요. 노동자들은 \n\n\nKBS\n\n1시간전\n\n\n\n\n\n\n\n\n배민 "로드러너 확대 계획 없다"⋯노조는 왜 반발하나\n\n배달의민족(배민)이 일부 지역에서 시범 운영 중인 라이더 배차 시스템 \'로드러너\'를 두고 배민과 라이더 측이 여전히 평행선을 달리고 있다. 도입 확대 여부를 둘러싼 시각차가 이어지면서 노사 간 입장차가 이어지고 있다\n\n\n아이뉴스24\n\n1시간전\n\n\n\n\n\n\n\n\n로봇팔, 갑자기 무거운 짐 들어도 안 떤다…‘적응형 제어기술’ 개발\n\n갑자기 무거운 짐을 들어도 덜덜 떨지 않는 로봇팔을 만드는 제어 기술이 나왔다. 산업 현장 로봇팔 90%에서 쓰는 제어기의 소프트웨어만 업데이트하면 바로 쓸 수 있는 기술이다. 울산과학기술원(UNIST) 기계공학과 \n\n\n부산일보\n\n1시간전\n\n\n\n\n\n\n\n\n[팩트체크K] “기본소득, 왜 ‘면(面)’에서만 써야 하나요?”…주민 반발\n\n[앵커] 충북에선 유일하게 옥천군 주민들이 2년 동안 매달 15만 원씩 기본소득을 지급받게 되는데요. 아직 지급되기도 전에 옥천의 면(面) 지역 주민들이 반발하고 있습니다. 상권이 몰려있는 읍(邑) 지역에선 기본소득\n\n\nKBS\n\n1시간전\n\n\n\n\n\n\n\n\n"개업 무섭다는데"⋯\'떡\' 돌리는 강남 공인중개업소\n\n"임대료에 광고 비용, 기본 운영비 등 중개사무소 운용에 매월 500만원은 고정비용으로 들어가죠. 매매뿐 아니라 전세 매물도 줄어서 거래가 안 되니 어렵 ...
