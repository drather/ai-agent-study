# %%
import bs4
import os
from dotenv import load_dotenv
# 올바른 임포트 경로로 수정
from langchain_community.document_loaders import PyMuPDFLoader # PyPDFLoader 대신 사용
from langchain_text_splitters import RecursiveCharacterTextSplitter
from langchain_openai import ChatOpenAI, OpenAIEmbeddings
from langchain_community.vectorstores import Chroma
from langchain_classic.retrievers.multi_query import MultiQueryRetriever

from ch07.main import text_spliter

load_dotenv()
openai_api_key = os.getenv("OPENAI_API_KEY")

if not openai_api_key:
    raise ValueError("openai api 키가 없습니다. 한번더 확인 부탁드립니다.")

# 환경 변수 설정
os.environ['OPENAI_API_KEY'] = openai_api_key
# Out:
# 2026-01-31 14:25:40.846 WARNING streamlit.runtime.scriptrunner_utils.script_run_context: Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-31 14:25:40.871
#   Warning: to view this Streamlit app on a browser, run it with the following
#   command:
#
#     streamlit run /Users/kks/Desktop/Laboratory/jocoding_langchain/env/lib/python3.12/site-packages/ipykernel_launcher.py [ARGUMENTS]
# 2026-01-31 14:25:40.871 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-31 14:25:40.872 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-31 14:25:40.872 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-31 14:25:40.872 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-31 14:25:40.872 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-31 14:25:40.873 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-31 14:25:40.874 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-31 14:25:40.875 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-31 14:25:40.876 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-31 14:25:40.876 Session state does not function when running a script without `streamlit run`
# 2026-01-31 14:25:40.877 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-31 14:25:40.877 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-31 14:25:40.878 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-31 14:25:40.879 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-31 14:25:40.879 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-31 14:25:40.880 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-31 14:25:40.881 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-31 14:25:40.881 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-31 14:25:40.882 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-31 14:25:40.882 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-31 14:25:40.883 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-31 14:25:40.883 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-31 14:25:40.884 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-31 14:25:40.884 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-31 14:25:40.885 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-31 14:25:40.886 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-31 14:25:40.886 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-31 14:25:40.887 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[2], line 11
#       8 from langchain_community.vectorstores import Chroma
#       9 from langchain_classic.retrievers.multi_query import MultiQueryRetriever
# ---> 11 from ch07.main import text_spliter
#      13 load_dotenv()
#      14 openai_api_key = os.getenv("OPENAI_API_KEY")
#
# ImportError: cannot import name 'text_spliter' from 'ch07.main' (/Users/kks/Desktop/Laboratory/jocoding_langchain/ch07/main.py)

# %%
# Split
splits = text_spliter.split_documents(docs)

# INDEX
from langchain_openai import OpenAIEmbeddings
from langchain_community.vectorstores import Chroma

vectorstore = Chroma.fomr_documents(documents=splits, embedding=OpenAIEmbeddings())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 2
#       1 # Split
# ----> 2 splits = text_spliter.split_documents(docs)
#       4 # INDEX
#       5 from langchain_openai import OpenAIEmbeddings
#
# NameError: name 'text_spliter' is not defined

# %%
# retriever
chroma_retriever = vectorstore.as_retriever(
    search_type="mmr",
    search_kwargs={'k': 1, 'fetch_k': 4}
)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 2
#       1 # retriever
# ----> 2 chroma_retriever = vectorstore.as_retriever(
#       3     search_type="mmr",
#       4     search_kwargs={'k': 1, 'fetch_k': 4}
#       5 )
#
# NameError: name 'vectorstore' is not defined
